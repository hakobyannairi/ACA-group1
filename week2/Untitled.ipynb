# %%
import pandas as pd
df = pd.read_csv('houses_train.csv')

# %%
df
# Out:
#       Unnamed: 0     price       condition          district  max_floor  \
# 0           5546  130000.0  newly repaired            Center          4
# 1           2979   65000.0            good           Arabkir          5
# 2           2698  129000.0            good            Center         10
# 3           4548   52000.0  newly repaired            Center         14
# 4           2982   65000.0  newly repaired            Center         12
# ...          ...       ...             ...               ...        ...
# 4995        2417   56000.0            good         Davtashen         16
# 4996        1307  115000.0            good           Arabkir          6
# 4997        2863  127000.0  newly repaired            Center          9
# 4998        1470   41800.0            good            Center          5
# 4999        1272   36000.0            good  Malatia-Sebastia         14
#
#                     street  num_rooms   region   area  \
# ...
